# %%
import pandas as pd

image_id = []
dim0 = []
dim1= []
splits = []

meta = pd.DataFrame.from_dict({'image_id': image_id, 'dim0': dim0, 'dim1': dim1, 'split': splits})
print(meta)
meta = meta[meta['split']=='test']
print(meta)
# Out:
# Empty DataFrame
# Columns: [image_id, dim0, dim1, split]
# Index: []

# %%
import numpy as np
import tensorflow as tf

x = np.random.sample((10, 2))
print(x)
dataset = tf.data.Dataset.from_tensor_slices(x)
# Out:
# [[0.8680966  0.4763222 ]
#  [0.51730498 0.05476534]
#  [0.08858835 0.63015827]
#  [0.58965361 0.61245958]
#  [0.04734324 0.56851819]
#  [0.99307512 0.88099531]
#  [0.74725037 0.61976647]
#  [0.76554663 0.74667283]
#  [0.61117908 0.24872156]
#  [0.15961845 0.26460369]]

# %%
print(x.shape, dataset)
# Out:
# (10, 2) <TensorSliceDataset shapes: (2,), types: tf.float64>

# %%
y = np.random.sample(10)
print(y)
# Out:
# [0.93387677 0.0121696  0.13466068 0.25574307 0.10994172 0.82773306
#  0.4627442  0.35076271 0.20026133 0.74832776]

# %%
dataset.shuffle(1024)
# Out:
# <ShuffleDataset shapes: (2,), types: tf.float64>

# %%
import tensorflow as tf
from tensorflow.python.keras.models import load_model
from tensorflow.keras.layers import Dropout
FixedDropout = Dropout(.2)
# layer = tf.keras.layers.Dropout(.2, input_shape=(2,))

# new_test_model = load_model("/content/drive/MyDrive/files/model0.h5", 
#                             custom_objects= {'FixedDropout' : FixedDropout}
#                             )

models0 = tf.keras.models.load_model(
    "/content/drive/MyDrive/files/model0.h5",
    custom_objects = {'FixedDropout' : Dropout}
    )
models1 = tf.keras.models.load_model(
    "/content/drive/MyDrive/files/model1.h5",
    custom_objects = {'FixedDropout' : Dropout}
)
# models0.drop(['FixedDropout'], axis=1)

# %%
models2 = tf.keras.models.load_model(
    "/content/drive/MyDrive/files/model2.h5",
    custom_objects = {'FixedDropout' : Dropout}
)

models3 = tf.keras.models.load_model(
    "/content/drive/MyDrive/files/model3.h5",
    custom_objects = {'FixedDropout' : Dropout}
)

models4 = tf.keras.models.load_model(
    "/content/drive/MyDrive/files/model4.h5",
    custom_objects = {'FixedDropout' : Dropout}
)

# %%
print(models2.summary())
print(models3.summary())
print(models4.summary())
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  efficientnet-b7 (Functional  (None, 19, 19, 2560)     64097680
#  )
#
#  global_average_pooling2d_2   (None, 2560)             0
#  (GlobalAveragePooling2D)
#
#  dense_2 (Dense)             (None, 4)                 10244
#
# ...
# Total params: 64,107,924
# Trainable params: 63,797,204
# Non-trainable params: 310,720
# _________________________________________________________________
# None
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  efficientnet-b7 (Functional  (None, 19, 19, 2560)     64097680
#  )
#
#  global_average_pooling2d_3   (None, 2560)             0
#  (GlobalAveragePooling2D)
#
#  dense_3 (Dense)             (None, 4)                 10244
#
# ...
# Total params: 64,107,924
# Trainable params: 63,797,204
# ...

# %%
models0.summary()
# print(models0, models0.summary)
# for layer_ in models0.layers:
#     print(layer_)
#     print(layer_.get_output_at(0).get_shape().as_list())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  efficientnet-b7 (Functional  (None, 19, 19, 2560)     64097680
#  )
#
#  global_average_pooling2d (G  (None, 2560)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 4)                 10244
#
# ...
# Total params: 64,107,924
# Trainable params: 63,797,204
# Non-trainable params: 310,720
# _________________________________________________________________

# %%
models1.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  efficientnet-b7 (Functional  (None, 19, 19, 2560)     64097680
#  )
#
#  global_average_pooling2d_1   (None, 2560)             0
#  (GlobalAveragePooling2D)
#
#  dense_1 (Dense)             (None, 4)                 10244
#
# ...
# Total params: 64,107,924
# Trainable params: 63,797,204
# Non-trainable params: 310,720
# _________________________________________________________________

# %%
# from IPython.display import SVG
# from tensorflow.python.keras.utils.vis_utils import model_to_dot

# %matplotlib inline

# SVG(model_to_dot(models0,show_shapes=True).create(prog='dot',format='svg'))
